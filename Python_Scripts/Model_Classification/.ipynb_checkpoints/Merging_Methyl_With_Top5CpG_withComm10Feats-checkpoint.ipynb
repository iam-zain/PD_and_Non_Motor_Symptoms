# %%
import pandas as pd
import numpy as np

# %%
# %cd Z:\PPMI_Data\Excel_Data\Raw_And_More
df = pd.read_csv ("beta_post_Funnorm_PPMI_EPICn524final030618.csv")
df = df.round(decimals = 4)
df.head(2)
# Out:
# Z:\PPMI_Data\Excel_Data\Raw_And_More
#             200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# cg14817997               0.8340               0.8492               0.7730
# cg26928153               0.9456               0.9485               0.9622
#
#             200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# cg14817997               0.8853               0.7725               0.7564
# cg26928153               0.9440               0.9263               0.9561
#
#             200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  \
# cg14817997               0.7198               0.7759               0.7689
# cg26928153               0.9130               0.9560               0.9571
#
#             200973410167_R05C01  ...  200989060089_R02C01  \
# cg14817997               0.7594  ...               0.7882
# cg26928153               0.8976  ...               0.9512
#
#             200989060089_R01C01  200989060089_R04C01  200973410143_R08C01  \
# cg14817997               0.8389               0.8453               0.7704
# cg26928153               0.9590               0.9571               0.9547
#
#             200973410143_R07C01  200989060089_R03C01  200989060150_R04C01  \
# cg14817997               0.8529               0.7838               0.8069
# cg26928153               0.9478               0.9581               0.9480
#
#             200989060150_R05C01  200989060150_R06C01  200991620049_R08C01
# cg14817997               0.8757               0.6613               0.7379
# cg26928153               0.9424               0.9550               0.9463
#
# [2 rows x 524 columns]

# %%
df.index.name ='CpG'
df.reset_index(inplace=True)
df.head(2)
# Out:
#           CpG  200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# 0  cg14817997               0.8340               0.8492               0.7730
# 1  cg26928153               0.9456               0.9485               0.9622
#
#    200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# 0               0.8853               0.7725               0.7564
# 1               0.9440               0.9263               0.9561
#
#    200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  ...  \
# 0               0.7198               0.7759               0.7689  ...
# 1               0.9130               0.9560               0.9571  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# 0               0.7882               0.8389               0.8453
# 1               0.9512               0.9590               0.9571
#
#    200973410143_R08C01  200973410143_R07C01  200989060089_R03C01  \
# 0               0.7704               0.8529               0.7838
# 1               0.9547               0.9478               0.9581
#
#    200989060150_R04C01  200989060150_R05C01  200989060150_R06C01  \
# 0               0.8069               0.8757               0.6613
# 1               0.9480               0.9424               0.9550
#
#    200991620049_R08C01
# 0               0.7379
# 1               0.9463
#
# [2 rows x 525 columns]

# %%
dframe = pd.read_csv ('Top5CpGBoruta_FromAPP1vs2_9Feats.csv')
dframe.head(2)
# Out:
#           CpG
# 0  cg00052836
# 1  cg00356916

# %%
dfMerge = pd.merge (df, dframe, on= "CpG", how= "inner")
dfMerge.head(2)
# Out:
#           CpG  200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# 0  cg24183574               0.9429               0.8964               0.9326
# 1  cg00356916               0.8087               0.8478               0.8932
#
#    200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# 0               0.9518               0.9393               0.9406
# 1               0.8736               0.8371               0.8469
#
#    200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  ...  \
# 0               0.9239               0.9449               0.9345  ...
# 1               0.8516               0.7771               0.8192  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# 0               0.9364               0.9308               0.9499
# 1               0.8568               0.8314               0.8517
#
#    200973410143_R08C01  200973410143_R07C01  200989060089_R03C01  \
# 0               0.9308               0.9429               0.9305
# 1               0.8566               0.4839               0.8516
#
#    200989060150_R04C01  200989060150_R05C01  200989060150_R06C01  \
# 0               0.9506               0.9333               0.9439
# 1               0.8751               0.8761               0.8766
#
#    200991620049_R08C01
# 0               0.9324
# 1               0.8921
#
# [2 rows x 525 columns]

# %%
dft = dfMerge.transpose()
dft.head(2)
# Out:
#                              0           1           2           3   \
# CpG                  cg24183574  cg00356916  cg02152968  cg16764955
# 200973410159_R03C01      0.9429      0.8087       0.269      0.9314
#
#                              4           5           6           7   \
# CpG                  cg03682895  cg05142211  cg27281389  cg18003698
# 200973410159_R03C01      0.9096      0.0196      0.0356      0.9365
#
#                              8           9   ...          26          27  \
# CpG                  cg12683454  cg03315407  ...  cg13818654  cg12103037
# 200973410159_R03C01      0.0208      0.0501  ...      0.0835      0.0762
#
#                              28          29          30          31  \
# CpG                  cg00377727  cg01685521  cg24215869  cg19371224
# 200973410159_R03C01      0.6784      0.9504      0.3951      0.8952
#
#                              32          33          34          35
# CpG                  cg19816560  cg24467842  cg12220605  cg18473117
# 200973410159_R03C01      0.0386      0.8305      0.1173      0.9672
#
# [2 rows x 36 columns]

# %%
dft.rename(columns=dft.iloc[0], inplace = True)

# %%
dft.index.name ='CpG'
dft.reset_index(inplace=True)
dft.head(2)
# Out:
#                    CpG  cg24183574  cg00356916  cg02152968  cg16764955  \
# 0                  CpG  cg24183574  cg00356916  cg02152968  cg16764955
# 1  200973410159_R03C01      0.9429      0.8087       0.269      0.9314
#
#    cg03682895  cg05142211  cg27281389  cg18003698  cg12683454  ...  \
# 0  cg03682895  cg05142211  cg27281389  cg18003698  cg12683454  ...
# 1      0.9096      0.0196      0.0356      0.9365      0.0208  ...
#
#    cg13818654  cg12103037  cg00377727  cg01685521  cg24215869  cg19371224  \
# 0  cg13818654  cg12103037  cg00377727  cg01685521  cg24215869  cg19371224
# 1      0.0835      0.0762      0.6784      0.9504      0.3951      0.8952
#
#    cg19816560  cg24467842  cg12220605  cg18473117
# 0  cg19816560  cg24467842  cg12220605  cg18473117
# 1      0.0386      0.8305      0.1173      0.9672
#
# [2 rows x 37 columns]

# %%
dft = dft.drop ([0], axis = 0)
dft.head(2)
# Out:
#                    CpG cg24183574 cg00356916 cg02152968 cg16764955 cg03682895  \
# 1  200973410159_R03C01     0.9429     0.8087      0.269     0.9314     0.9096
# 2  200991620021_R01C01     0.8964     0.8478     0.2634     0.9177     0.9027
#
#   cg05142211 cg27281389 cg18003698 cg12683454  ... cg13818654 cg12103037  \
# 1     0.0196     0.0356     0.9365     0.0208  ...     0.0835     0.0762
# 2      0.035     0.0269     0.8573     0.0238  ...     0.0668     0.0864
#
#   cg00377727 cg01685521 cg24215869 cg19371224 cg19816560 cg24467842  \
# 1     0.6784     0.9504     0.3951     0.8952     0.0386     0.8305
# 2     0.9233      0.963     0.3458     0.7516     0.0215     0.8747
#
#   cg12220605 cg18473117
# 1     0.1173     0.9672
# 2     0.0824     0.9388
#
# [2 rows x 37 columns]

# %%
dft.rename (columns = {"CpG" : "Sentrix"}, inplace = True)
dft.head(2)
# Out:
#                Sentrix cg24183574 cg00356916 cg02152968 cg16764955 cg03682895  \
# 1  200973410159_R03C01     0.9429     0.8087      0.269     0.9314     0.9096
# 2  200991620021_R01C01     0.8964     0.8478     0.2634     0.9177     0.9027
#
#   cg05142211 cg27281389 cg18003698 cg12683454  ... cg13818654 cg12103037  \
# 1     0.0196     0.0356     0.9365     0.0208  ...     0.0835     0.0762
# 2      0.035     0.0269     0.8573     0.0238  ...     0.0668     0.0864
#
#   cg00377727 cg01685521 cg24215869 cg19371224 cg19816560 cg24467842  \
# 1     0.6784     0.9504     0.3951     0.8952     0.0386     0.8305
# 2     0.9233      0.963     0.3458     0.7516     0.0215     0.8747
#
#   cg12220605 cg18473117
# 1     0.1173     0.9672
# 2     0.0824     0.9388
#
# [2 rows x 37 columns]

# %%
df2 = pd.read_csv ("Comm10FeatData_withBasicDetails.csv")
df2.head(2)
# Out:
#                Sentrix  PATNO  Gender  APPRDX  HYS   Age  AgeCate  \
# 0  200973410159_R03C01   3000       2       2    0  69.1        4
# 1  200991620021_R01C01   3001       1       1    2  65.1        4
#
#    MDS_Depress  MDSP_Constipate  MDSP_Fatigue  MDSP_LightHead  MDSP_SleepDay  \
# 0            1                0             0               0              1
# 1            0                0             1               0              1
#
#    MDSP_Pain  Montreal_Cognitive  SCOPA_Sex  Symbol_Digit  UPSIT_3
# 0          0                   0          0             0        0
# 1          0                   0          2             1        1

# %%
df3 = pd.merge (df2, dft, on= "Sentrix", how= "inner")
df3.head(2)
# Out:
#                Sentrix  PATNO  Gender  APPRDX  HYS   Age  AgeCate  \
# 0  200973410159_R03C01   3000       2       2    0  69.1        4
# 1  200991620021_R01C01   3001       1       1    2  65.1        4
#
#    MDS_Depress  MDSP_Constipate  MDSP_Fatigue  ...  cg13818654  cg12103037  \
# 0            1                0             0  ...      0.0835      0.0762
# 1            0                0             1  ...      0.0668      0.0864
#
#    cg00377727  cg01685521  cg24215869  cg19371224  cg19816560 cg24467842  \
# 0      0.6784      0.9504      0.3951      0.8952      0.0386     0.8305
# 1      0.9233       0.963      0.3458      0.7516      0.0215     0.8747
#
#   cg12220605 cg18473117
# 0     0.1173     0.9672
# 1     0.0824     0.9388
#
# [2 rows x 53 columns]

# %%
df3.shape
# Out:
# (457, 53)

# %%
df3.to_csv ("CpG36_Top5_BorutaAPP1vs2_9Feats_withComm10Feat_withMethyl.csv", index = False)
