# %%
import pandas as pd
import numpy as np

# %%
# %cd Z:\PPMI_Data\Excel_Data\Raw_And_More
df = pd.read_csv ("beta_post_Funnorm_PPMI_EPICn524final030618.csv")
df = df.round(decimals = 4)
df.head(2)
# Out:
# Z:\PPMI_Data\Excel_Data\Raw_And_More
#             200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# cg14817997               0.8340               0.8492               0.7730
# cg26928153               0.9456               0.9485               0.9622
#
#             200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# cg14817997               0.8853               0.7725               0.7564
# cg26928153               0.9440               0.9263               0.9561
#
#             200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  \
# cg14817997               0.7198               0.7759               0.7689
# cg26928153               0.9130               0.9560               0.9571
#
#             200973410167_R05C01  ...  200989060089_R02C01  \
# cg14817997               0.7594  ...               0.7882
# cg26928153               0.8976  ...               0.9512
#
#             200989060089_R01C01  200989060089_R04C01  200973410143_R08C01  \
# cg14817997               0.8389               0.8453               0.7704
# cg26928153               0.9590               0.9571               0.9547
#
#             200973410143_R07C01  200989060089_R03C01  200989060150_R04C01  \
# cg14817997               0.8529               0.7838               0.8069
# cg26928153               0.9478               0.9581               0.9480
#
#             200989060150_R05C01  200989060150_R06C01  200991620049_R08C01
# cg14817997               0.8757               0.6613               0.7379
# cg26928153               0.9424               0.9550               0.9463
#
# [2 rows x 524 columns]

# %%
df.index.name ='CpG'
df.reset_index(inplace=True)
df.head(2)
# Out:
#           CpG  200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# 0  cg14817997               0.8340               0.8492               0.7730
# 1  cg26928153               0.9456               0.9485               0.9622
#
#    200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# 0               0.8853               0.7725               0.7564
# 1               0.9440               0.9263               0.9561
#
#    200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  ...  \
# 0               0.7198               0.7759               0.7689  ...
# 1               0.9130               0.9560               0.9571  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# 0               0.7882               0.8389               0.8453
# 1               0.9512               0.9590               0.9571
#
#    200973410143_R08C01  200973410143_R07C01  200989060089_R03C01  \
# 0               0.7704               0.8529               0.7838
# 1               0.9547               0.9478               0.9581
#
#    200989060150_R04C01  200989060150_R05C01  200989060150_R06C01  \
# 0               0.8069               0.8757               0.6613
# 1               0.9480               0.9424               0.9550
#
#    200991620049_R08C01
# 0               0.7379
# 1               0.9463
#
# [2 rows x 525 columns]

# %%
dframe = pd.read_csv ('CpG_AboveNMI.05_AllChrin_APP1vs2.csv')
dframe.head(2)
# Out:
#           CpG
# 0  cg10991923
# 1  cg16881640

# %%
dfMerge = pd.merge (df, dframe, on= "CpG", how= "inner")
dfMerge.head(2)
# Out:
#           CpG  200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# 0  cg00894481               0.7124               0.7681               0.8569
# 1  cg26408382               0.9030               0.9224               0.9156
#
#    200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# 0               0.7722               0.7143               0.7208
# 1               0.9128               0.8930               0.9210
#
#    200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  ...  \
# 0               0.6112               0.7601               0.7718  ...
# 1               0.9052               0.9168               0.9256  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# 0               0.7544               0.7890               0.7231
# 1               0.9012               0.8989               0.9078
#
#    200973410143_R08C01  200973410143_R07C01  200989060089_R03C01  \
# 0               0.8565               0.7759               0.7671
# 1               0.9145               0.9216               0.9108
#
#    200989060150_R04C01  200989060150_R05C01  200989060150_R06C01  \
# 0               0.7455               0.7449               0.7658
# 1               0.9138               0.9291               0.9274
#
#    200991620049_R08C01
# 0               0.7853
# 1               0.9154
#
# [2 rows x 525 columns]

# %%
dft = dfMerge.transpose()
dft.head(2)
# Out:
#                              0           1           2           3   \
# CpG                  cg00894481  cg26408382  cg06796611  cg06061283
# 200973410159_R03C01      0.7124       0.903      0.7825      0.8702
#
#                              4           5           6           7   \
# CpG                  cg21672780  cg07569562  cg07617207  cg11670533
# 200973410159_R03C01      0.9244      0.9243      0.9256      0.8498
#
#                              8           9   ...          48          49  \
# CpG                  cg14707886  cg23193209  ...  cg01571840  cg19726935
# 200973410159_R03C01      0.7842       0.878  ...      0.9161      0.7926
#
#                              50          51          52          53  \
# CpG                  cg24009439  cg24374538  cg22151539  cg21890309
# 200973410159_R03C01      0.9665      0.1581       0.824      0.9807
#
#                              54          55          56          57
# CpG                  cg22963164  cg04685632  cg26417244  cg15469205
# 200973410159_R03C01       0.891      0.9202      0.9081      0.6569
#
# [2 rows x 58 columns]

# %%
dft.rename(columns=dft.iloc[0], inplace = True)

# %%
dft.index.name ='CpG'
dft.reset_index(inplace=True)
dft.head(2)
# Out:
#                    CpG  cg00894481  cg26408382  cg06796611  cg06061283  \
# 0                  CpG  cg00894481  cg26408382  cg06796611  cg06061283
# 1  200973410159_R03C01      0.7124       0.903      0.7825      0.8702
#
#    cg21672780  cg07569562  cg07617207  cg11670533  cg14707886  ...  \
# 0  cg21672780  cg07569562  cg07617207  cg11670533  cg14707886  ...
# 1      0.9244      0.9243      0.9256      0.8498      0.7842  ...
#
#    cg01571840  cg19726935  cg24009439  cg24374538  cg22151539  cg21890309  \
# 0  cg01571840  cg19726935  cg24009439  cg24374538  cg22151539  cg21890309
# 1      0.9161      0.7926      0.9665      0.1581       0.824      0.9807
#
#    cg22963164  cg04685632  cg26417244  cg15469205
# 0  cg22963164  cg04685632  cg26417244  cg15469205
# 1       0.891      0.9202      0.9081      0.6569
#
# [2 rows x 59 columns]

# %%
dft = dft.drop ([0], axis = 0)
dft.head(2)
# Out:
#                    CpG cg00894481 cg26408382 cg06796611 cg06061283 cg21672780  \
# 1  200973410159_R03C01     0.7124      0.903     0.7825     0.8702     0.9244
# 2  200991620021_R01C01     0.7681     0.9224      0.729      0.732     0.9126
#
#   cg07569562 cg07617207 cg11670533 cg14707886  ... cg01571840 cg19726935  \
# 1     0.9243     0.9256     0.8498     0.7842  ...     0.9161     0.7926
# 2     0.8898     0.8767     0.7905     0.8465  ...     0.9195     0.6946
#
#   cg24009439 cg24374538 cg22151539 cg21890309 cg22963164 cg04685632  \
# 1     0.9665     0.1581      0.824     0.9807      0.891     0.9202
# 2     0.9657     0.0977     0.7136     0.9733     0.7354     0.8675
#
#   cg26417244 cg15469205
# 1     0.9081     0.6569
# 2     0.8952     0.8659
#
# [2 rows x 59 columns]

# %%
dft.rename (columns = {"CpG" : "Sentrix"}, inplace = True)
dft.head(2)
# Out:
#                Sentrix cg00894481 cg26408382 cg06796611 cg06061283 cg21672780  \
# 1  200973410159_R03C01     0.7124      0.903     0.7825     0.8702     0.9244
# 2  200991620021_R01C01     0.7681     0.9224      0.729      0.732     0.9126
#
#   cg07569562 cg07617207 cg11670533 cg14707886  ... cg01571840 cg19726935  \
# 1     0.9243     0.9256     0.8498     0.7842  ...     0.9161     0.7926
# 2     0.8898     0.8767     0.7905     0.8465  ...     0.9195     0.6946
#
#   cg24009439 cg24374538 cg22151539 cg21890309 cg22963164 cg04685632  \
# 1     0.9665     0.1581      0.824     0.9807      0.891     0.9202
# 2     0.9657     0.0977     0.7136     0.9733     0.7354     0.8675
#
#   cg26417244 cg15469205
# 1     0.9081     0.6569
# 2     0.8952     0.8659
#
# [2 rows x 59 columns]

# %%
df2 = pd.read_csv ("Comm10FeatData_withBasicDetails.csv")
df2.head(2)
# Out:
#                Sentrix  PATNO  Gender  APPRDX  HYS   Age  AgeCate  \
# 0  200973410159_R03C01   3000       2       2    0  69.1        4
# 1  200991620021_R01C01   3001       1       1    2  65.1        4
#
#    MDS_Depress  MDSP_Constipate  MDSP_Fatigue  MDSP_LightHead  MDSP_SleepDay  \
# 0            1                0             0               0              1
# 1            0                0             1               0              1
#
#    MDSP_Pain  Montreal_Cognitive  SCOPA_Sex  Symbol_Digit  UPSIT_3
# 0          0                   0          0             0        0
# 1          0                   0          2             1        1

# %%
df3 = pd.merge (df2, dft, on= "Sentrix", how= "inner")
df3.head(2)
# Out:
#                Sentrix  PATNO  Gender  APPRDX  HYS   Age  AgeCate  \
# 0  200973410159_R03C01   3000       2       2    0  69.1        4
# 1  200991620021_R01C01   3001       1       1    2  65.1        4
#
#    MDS_Depress  MDSP_Constipate  MDSP_Fatigue  ...  cg01571840  cg19726935  \
# 0            1                0             0  ...      0.9161      0.7926
# 1            0                0             1  ...      0.9195      0.6946
#
#    cg24009439  cg24374538  cg22151539  cg21890309  cg22963164 cg04685632  \
# 0      0.9665      0.1581       0.824      0.9807       0.891     0.9202
# 1      0.9657      0.0977      0.7136      0.9733      0.7354     0.8675
#
#   cg26417244 cg15469205
# 0     0.9081     0.6569
# 1     0.8952     0.8659
#
# [2 rows x 75 columns]

# %%
df3.shape
# Out:
# (457, 75)

# %%
df3.to_csv ("CpG_AboveNMI.05inAllChr_withComm10FeatData_withMethylDetail.csv", index = False)
