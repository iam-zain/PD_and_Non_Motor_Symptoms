# %%
import umap
import hdbscan
import numpy as np
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.cluster as cluster
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
# %matplotlib inline

# %%
# %cd Z:\PPMI_Data\Excels\NonMotors\The251\Files
df = pd.read_csv('Feats45_Categ.csv')
print(df.shape)
df.head(2)
# Out:
# Z:\PPMI_Data\Excels\NonMotors\The251\Files
# (251, 46)
#    APPRDX  Benton  Clock  COGSTATE  Epworth  Geriatric_Depression  \
# 0       1       0      0         0        1                     1
# 1       1       0      1         0        0                     1
#
#    Hopkins_Recall  Hopkins_Recog  LetterNumber  Lexical_Fluency  ...  \
# 0               0              0             1                1  ...
# 1               0              0             1                1  ...
#
#    SCOPA_Sex  Semantic  Education  Hand  STAIS  STAIA  Symbol_Digit  \
# 0          1         0          1     0      2      1             1
# 1          0         2          1     0      0      0             1
#
#    Trail_Making_A  Trail_Making_B  UPSIT
# 0               2               1      2
# 1               0               0      2
#
# [2 rows x 46 columns]

# %%
df_data = df.drop(['APPRDX'], axis=1)
df_data.head(2)
# Out:
#    Benton  Clock  COGSTATE  Epworth  Geriatric_Depression  Hopkins_Recall  \
# 0       0      0         0        1                     1               0
# 1       0      1         0        0                     1               0
#
#    Hopkins_Recog  LetterNumber  Lexical_Fluency  MDSP_SleepNight  ...  \
# 0              0             1                1                0  ...
# 1              0             1                1                2  ...
#
#    SCOPA_Sex  Semantic  Education  Hand  STAIS  STAIA  Symbol_Digit  \
# 0          1         0          1     0      2      1             1
# 1          0         2          1     0      0      0             1
#
#    Trail_Making_A  Trail_Making_B  UPSIT
# 0               2               1      2
# 1               0               0      2
#
# [2 rows x 45 columns]

# %%
df_targets = df[['APPRDX']]

# %%
colors = {1:"#F1746B", 2: "#36C3D1"}

# %%
clusterable_embedding = umap.UMAP(n_neighbors=30, min_dist=0.0, n_components=2,random_state=42,).fit_transform(df_data)

# %%
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], marker='o',label='Scatter',markerfacecolor='#F1746B', markersize=30, color='floralwhite'),
                Line2D([0], [0], marker='o',label='Scatter',markerfacecolor='#36C3D1', markersize=30, color='floralwhite')]

# %%
plt.scatter(clusterable_embedding[:, 0], clusterable_embedding[:, 1],
c=df_targets['APPRDX'].map(colors), s=500, cmap="Spectral");
plt.rcParams["figure.figsize"] = [30,25]
plt.xlabel('UMAP 1', fontsize=60, fontweight='bold', color='black')
plt.ylabel('UMAP 2', fontsize=60, fontweight='bold', color='black')
plt.xticks(fontsize=50, fontweight='bold', color='black')
plt.yticks(fontsize=50, fontweight='bold', color='black')
plt.legend(custom_lines, ['Patient', 'Healthy Control'], loc='upper right',shadow = True,
           facecolor = 'floralwhite',prop = {'size' : 50})
plt.title(label= "UMAP - Non-motor symptoms", fontsize=60, fontweight='bold',
          color='black', pad= 20)
plt.savefig("UMAP_NonMototSymptoms_PatVsHealthy_Cat.pdf", format="pdf")
plt.savefig("UMAP_NonMototSymptoms_PatVsHealthy_Cat.svg", format="svg")
plt.show()
# Out:
# C:\Users\system 4\AppData\Local\Temp\ipykernel_11016\569850800.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(clusterable_embedding[:, 0], clusterable_embedding[:, 1],
